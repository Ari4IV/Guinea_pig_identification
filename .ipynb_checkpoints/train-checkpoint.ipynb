# %% [markdown]
# # 先導入所有需要的套件

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD
from ipywidgets import interact_manual

# %% [markdown]
# # 資料預處理

# %%
data_dir = './images'  # 資料夾的路徑
breeds = ['Abyssinian', 'American', 'Silkie', 'Skinny']
images = []
labels = []

for idx, breed in enumerate(breeds):
    breed_dir = os.path.join(data_dir, breed)
    for img_name in os.listdir(breed_dir):
        if not img_name.startswith('.'):  # 排除隱藏檔案
            img_path = os.path.join(breed_dir, img_name)
            img = load_img(img_path, target_size=(128, 128))
            images.append(img_to_array(img))
            labels.append(idx)

# 轉換成 numpy array
x_data = np.array(images, dtype='float32') / 255.  # 正規化
y_data = to_categorical(labels, num_classes=len(breeds))

# %% [markdown]
# # 切分資料

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

# %% [markdown]
# # 隨機查看一筆資料的長相

# %%
print(x_train.shape)
n = np.random.randint(x_train.shape[0])
plt.imshow(x_train[n], cmap='Greys')
plt.title(breeds[np.argmax(y_train[n])])
plt.show()
# Out:
# (1305, 128, 128, 3)

# %% [markdown]
# # 打造神經網路

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(len(breeds), activation='softmax')
])

# %% [markdown]
# # 組裝神經網路

# %%
model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.01), metrics=['accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %% [markdown]
# # 查看模型結構

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dense (Dense)               (None, 128)               7372928
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 7392836 (28.20 MB)
# Trainable params: 7392836 (28.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # 訓練

# %%
model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 5s 113ms/step - loss: 1.3407 - accuracy: 0.3303 - val_loss: 1.2987 - val_accuracy: 0.3761
# Epoch 2/100
# 41/41 [==============================] - 4s 101ms/step - loss: 1.3138 - accuracy: 0.3724 - val_loss: 1.3015 - val_accuracy: 0.4220
# Epoch 3/100
# 41/41 [==============================] - 4s 102ms/step - loss: 1.2899 - accuracy: 0.4153 - val_loss: 1.2865 - val_accuracy: 0.3456
# Epoch 4/100
# 41/41 [==============================] - 4s 101ms/step - loss: 1.2672 - accuracy: 0.4054 - val_loss: 1.3106 - val_accuracy: 0.3914
# Epoch 5/100
# 41/41 [==============================] - 4s 101ms/step - loss: 1.2500 - accuracy: 0.4337 - val_loss: 1.2397 - val_accuracy: 0.4679
# Epoch 6/100
# 41/41 [==============================] - 4s 102ms/step - loss: 1.2239 - accuracy: 0.4582 - val_loss: 1.2010 - val_accuracy: 0.4862
# Epoch 7/100
# 41/41 [==============================] - 4s 102ms/step - loss: 1.2100 - accuracy: 0.4536 - val_loss: 1.1941 - val_accuracy: 0.4587
# Epoch 8/100
# 41/41 [==============================] - 4s 103ms/step - loss: 1.1708 - accuracy: 0.4935 - val_loss: 1.2142 - val_accuracy: 0.4373
# Epoch 9/100
# 41/41 [==============================] - 4s 103ms/step - loss: 1.1525 - accuracy: 0.5050 - val_loss: 1.2221 - val_accuracy: 0.4159
# Epoch 10/100
# 41/41 [==============================] - 4s 106ms/step - loss: 1.1307 - accuracy: 0.4927 - val_loss: 1.2299 - val_accuracy: 0.4159
# Epoch 11/100
# 41/41 [==============================] - 4s 104ms/step - loss: 1.1032 - accuracy: 0.5287 - val_loss: 1.1754 - val_accuracy: 0.4526
# Epoch 12/100
# 41/41 [==============================] - 4s 107ms/step - loss: 1.0681 - accuracy: 0.5586 - val_loss: 1.1365 - val_accuracy: 0.4954
# Epoch 13/100
# 41/41 [==============================] - 4s 107ms/step - loss: 1.0480 - accuracy: 0.5762 - val_loss: 1.2303 - val_accuracy: 0.4128
# Epoch 14/100
100
# 41/41 [==============================] - 6s 141ms/step - loss: 0.0116 - accuracy: 0.9977 - val_loss: 1.6625 - val_accuracy: 0.6269
# Epoch 66/100
# 41/41 [==============================] - 7s 175ms/step - loss: 0.0106 - accuracy: 0.9977 - val_loss: 1.6890 - val_accuracy: 0.6239
# Epoch 67/100
# 41/41 [==============================] - 7s 168ms/step - loss: 0.0138 - accuracy: 0.9969 - val_loss: 1.7869 - val_accuracy: 0.5994
# Epoch 68/100
# 41/41 [==============================] - 7s 162ms/step - loss: 0.0139 - accuracy: 0.9977 - val_loss: 1.7187 - val_accuracy: 0.6269
# Epoch 69/100
# 41/41 [==============================] - 6s 155ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 1.7808 - val_accuracy: 0.6239
# Epoch 70/100
# 41/41 [==============================] - 6s 150ms/step - loss: 0.0097 - accuracy: 0.9977 - val_loss: 1.7371 - val_accuracy: 0.6086
# Epoch 71/100
# 41/41 [==============================] - 7s 168ms/step - loss: 0.0062 - accuracy: 0.9992 - val_loss: 1.7087 - val_accuracy: 0.6208
# Epoch 72/100
# 41/41 [==============================] - 6s 145ms/step - loss: 0.0091 - accuracy: 0.9985 - val_loss: 1.7427 - val_accuracy: 0.6208
# Epoch 73/100
# 41/41 [==============================] - 6s 141ms/step - loss: 0.0090 - accuracy: 0.9977 - val_loss: 1.7743 - val_accuracy: 0.6208
# Epoch 74/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.0077 - accuracy: 0.9992 - val_loss: 1.7510 - val_accuracy: 0.6147
# Epoch 75/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0115 - accuracy: 0.9977 - val_loss: 1.7329 - val_accuracy: 0.6177
# Epoch 76/100
# 41/41 [==============================] - 7s 163ms/step - loss: 0.0081 - accuracy: 0.9985 - val_loss: 1.7427 - val_accuracy: 0.6269
# Epoch 77/100
# 41/41 [==============================] - 6s 153ms/step - loss: 0.0126 - accuracy: 0.9977 - val_loss: 1.7269 - val_accuracy: 0.6239
# Epoch 78/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 1.7768 - val_accuracy: 0.6147
# Epoch 79/100
# 41/41 [==============================] - 6s 142ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 1.7778 - val_accuracy: 0.6147
# Epoch 80/100
# 41/41 [==============================] - 7s 163ms/step - loss: 0.0070 - accuracy: 0.9985 - val_loss: 1.7842 - val_accuracy: 0.6239
# Epoch 81/100
# 41/41 [==============================] - 6s 150ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 1.8228 - val_accuracy: 0.6269
# Epoch 82/100
# 41/41 [==============================] - 6s 150ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 1.7892 - val_accuracy: 0.6208
# Epoch 83/100
# 41/41 [==============================] - 6s 140ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 1.7964 - val_accuracy: 0.6239
# Epoch 84/100
# 41/41 [==============================] - 6s 139ms/step - loss: 0.0080 - accuracy: 0.9962 - val_loss: 1.7945 - val_accuracy: 0.6177
# Epoch 85/100
# 41/41 [==============================] - 7s 173ms/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 1.7943 - val_accuracy: 0.6239
# Epoch 86/100
# 41/41 [==============================] - 6s 150ms/step - loss: 0.0039 - accuracy: 0.9992 - val_loss: 1.8199 - val_accuracy: 0.6208
# Epoch 87/100
# 41/41 [==============================] - 6s 141ms/step - loss: 0.0044 - accuracy: 0.9992 - val_loss: 1.8422 - val_accuracy: 0.6239
# Epoch 88/100
# 41/41 [==============================] - 6s 139ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 1.8352 - val_accuracy: 0.6116
# Epoch 89/100
# 41/41 [==============================] - 6s 140ms/step - loss: 0.0052 - accuracy: 0.9992 - val_loss: 1.8270 - val_accuracy: 0.6239
# Epoch 90/100
# 41/41 [==============================] - 6s 137ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 1.8446 - val_accuracy: 0.6147
# Epoch 91/100
# 41/41 [==============================] - 7s 162ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 1.8680 - val_accuracy: 0.6208
# Epoch 92/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0082 - accuracy: 0.9985 - val_loss: 1.8309 - val_accuracy: 0.6177
# Epoch 93/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 1.8931 - val_accuracy: 0.6147
# Epoch 94/100
# 41/41 [==============================] - 6s 136ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 2.0411 - val_accuracy: 0.6086
# Epoch 95/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0096 - accuracy: 0.9985 - val_loss: 1.8219 - val_accuracy: 0.6208
# Epoch 96/100
# 41/41 [==============================] - 6s 154ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 1.8570 - val_accuracy: 0.6116
# Epoch 97/100
# 41/41 [==============================] - 6s 142ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 1.8457 - val_accuracy: 0.6239
# Epoch 98/100
# 41/41 [==============================] - 6s 145ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 1.8609 - val_accuracy: 0.6208
# Epoch 99/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 1.8957 - val_accuracy: 0.6147
# Epoch 100/100
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 1.8762 - val_accuracy: 0.6147

# %% [markdown]
# # 預測

# %%
predictions = model.predict(x_test)
# Out:
# 11/11 [==============================] - 0s 31ms/step

# %% [markdown]
# # 評估正確率

# %%
accuracy = np.mean(np.argmax(predictions, axis=1) == np.argmax(y_test, axis=1))
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.61

# %% [markdown]
# # 儲存模型

# %%
model.save('./model/guinea_pig_model.h5')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
